# %% [markdown]
# # ****Data Preprocessing****

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("myexcel.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### **Data Story**
# The table is of 458 rows with 9 columns. The table is an employee data. By analysing the data, we find that the details given in the 'Height' column is wrongly assigned.

# %%
data["Height"] = np.random.randint(150, 180, size = len(data)) 
data.to_csv("Employee_detailsABC.csv", index = False) 
data1 = pd.read_csv("Employee_detailsABC.csv")

# %% [markdown]
# ### **Data Story**
# Here we changed the 'Height' column with 150cm and 180 cm and saved this file as another file named 'Employee_detailsABC.csv'.

# %%
data1.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     162     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2   John Holland  Boston Celtics      30       SG   27     176     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     171     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     153     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ### **Data Story**
# Shows the first five observation of the given data.

# %%
data1.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26     162     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24     169     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26     169     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     164     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25     169     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %% [markdown]
# ### **Data Story**
# Shows the last five observation of the given data.

# %%
data1.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# ### **Data Story**
# These are the column names of the employee data.

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %% [markdown]
# ### **Data Story**
# The information function provides the information of each and every column in the employee data. From this data, except the columns 'College' and 'Salary' every other column has no null values. Also, this provides the data types of each columns. The data types of columns 'Name', 'Team', 'Position', 'College' are object while data types of columns 'Number', 'Age', 'Height', 'Weight' are intergers with 64 bits whereas the column 'Salary' is float with 64 bits.

# %%
data1.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %% [markdown]
# ### **Data Story**
# The describe function mainly shows the statistical information of the data. This mainly shows counts(which shows number of cells are filled), frequency, mean, standard deviation, minimum, 1st quartile, 2nd quartile / median, 3rd quatile, maximum, etc.

# %%
data1.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ### **Data Story**
# To show the number of null information in each column. Data reveals that the columns 'College' and 'Salary' only have null values of 84 and 11 respectively while others have zero null values.

# %%
data1.loc[:, "Salary"]=data["Salary"].fillna(data["Salary"].mean()) 
data1.loc[:, "College"]=data["College"].fillna("Not Applicable")
data1.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %% [markdown]
# ### **Data Story**
# Filled the null value in Salary with their mean salary and College name with Not Applicable. Thus our data shows no null values for further analysis.

# %%
data1.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %% [markdown]
# ### **Data Story**
# Shows the unique values of the column 'Position'.

# %%
data1.College.unique()
# Out:
# array(['Texas', 'Marquette', 'Boston University', 'Georgia State',
#        'Not Applicable', 'LSU', 'Gonzaga', 'Louisville', 'Oklahoma State',
#        'Ohio State', 'Washington', 'Kentucky', 'North Carolina',
#        'Arizona', 'Georgia Tech', 'Cincinnati', 'Miami (FL)', 'Stanford',
#        'Syracuse', 'Saint Louis', 'Kansas', 'Georgetown', 'Texas A&M',
#        'UCLA', 'UNLV', 'Wichita State', "Saint Joseph's", 'Notre Dame',
#        'Norfolk State', 'Duke', 'Murray State', 'Tennessee State',
#        'Bowling Green', 'Purdue', 'Wake Forest', 'Michigan', 'Missouri',
#        'USC', 'Villanova', 'Rider', 'Utah', 'Belmont', 'Davidson',
#        'Vanderbilt', 'Michigan State', 'Florida', 'Washington State',
#        'Arizona State', 'Oklahoma', 'Wyoming', "St. John's", 'Maryland',
#        'Wisconsin', 'Utah Valley', 'North Carolina State',
#        'UC Santa Barbara', 'Baylor', 'Connecticut', 'Oregon State',
#        'New Mexico', 'Oregon', 'Creighton', 'Arkansas', 'Memphis',
# ...

# %% [markdown]
# ### **Data Story**
# Shows the unique values of the column 'College'.

# %%
data1.College.nunique()
# Out:
# 119

# %% [markdown]
# ### **Data Story**
# Shows the number of unique values of the column 'College'.

# %%
data1.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %% [markdown]
# ### **Data Story**
# Shows the unique values of the column 'Team'.

# %%
data1.Team.nunique()
# Out:
# 30

# %% [markdown]
# ### **Data Story**
# Shows the number of unique values of the column 'Team'.

# %%
data1.Age.unique()
# Out:
# array([25, 27, 22, 29, 21, 24, 20, 26, 28, 32, 23, 30, 33, 34, 37, 36, 31,
#        38, 39, 19, 35, 40])

# %% [markdown]
# ### **Data Story**
# Shows the unique values of the column 'Age'.

# %% [markdown]
#  # ****Data Visualization****

# %%
Team_frequency = data1.Team.value_counts() 
Team_percent = (Team_frequency / len(data1)) * 100 
Team = pd.DataFrame({"Count": Team_frequency, "Percentage": Team_percent}) 
Team
# Out:
#                         Count  Percentage
# Team
# New Orleans Pelicans       19    4.148472
# Memphis Grizzlies          18    3.930131
# Utah Jazz                  16    3.493450
# New York Knicks            16    3.493450
# Milwaukee Bucks            16    3.493450
# Brooklyn Nets              15    3.275109
# Portland Trail Blazers     15    3.275109
# Oklahoma City Thunder      15    3.275109
# Denver Nuggets             15    3.275109
# Washington Wizards         15    3.275109
# Miami Heat                 15    3.275109
# Charlotte Hornets          15    3.275109
# Atlanta Hawks              15    3.275109
# San Antonio Spurs          15    3.275109
# Houston Rockets            15    3.275109
# Boston Celtics             15    3.275109
# Indiana Pacers             15    3.275109
# Detroit Pistons            15    3.275109
# Cleveland Cavaliers        15    3.275109
# Chicago Bulls              15    3.275109
# Sacramento Kings           15    3.275109
# ...

# %% [markdown]
# ### **Data Story**
# The above table shows the number of people in each team and there and the percentage splitting with respect to the each employees

# %%
print(data1.Position.value_counts()) 
sns.barplot(x = ['SG', 'PF', 'PG', 'SF', 'C'], y = data1.Position.value_counts(), color = 'red', edgecolor = 'black', width = 0.4, zorder = 3) 
plt.grid(zorder = 0) 
plt.show()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# ### **Data Story**
# Segregating the employees w.r.t. the positions.

# %%
data1.Age.value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %% [markdown]
# ### **Data Story**
# The above table shows number of people having a particular age.

# %%
plt.hist(data1['Age'], bins = [18, 21, 24, 27, 30, 33, 36, 39, 42], edgecolor = 'black', color = 'y') 
plt.title('Frequency distribution of Age')
plt.xlabel('Age') 
plt.ylabel('Frequency') 
plt.ylim(0, 140)
plt.xlim(15, 45)

plt.show()

# %% [markdown]
# ### **Data Story**
# The graph shows different age group of employees.

# %%
data1[data1['Salary'] == data1['Salary'].max()]
# Out:
#             Name                Team  Number Position  Age  Height  Weight  \
# 109  Kobe Bryant  Los Angeles Lakers      24       SF   37     157     212
#
#             College      Salary
# 109  Not Applicable  25000000.0

# %% [markdown]
# ### **Data Story**
# Shows the employee who is getting highest salary.

# %%
group = data1.groupby(['Team', 'Position'])['Salary'].sum() 
group
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: object

# %% [markdown]
# ### **Data Story**
# Grouping the team and position to find out the salary spends according to team and their position wise.

# %%
group[group == group.max()]
# Out:
# Team                Position
# Los Angeles Lakers  SF          31866445.0
# Name: Salary, dtype: object

# %% [markdown]
# ### **Data Story**
# This result shows the team and position of that team who spends most money.

# %%
plt.scatter(data1['Age'], data1['Salary'], marker = '*', color = 'g', s = 25) 
plt.title("Relationship between 'Age' and 'Salary'.") 
plt.xlabel("Age") 
plt.ylabel("Salary")

plt.show()

# %% [markdown]
# ### **Data Story**
# The above scatter plot represents the relationship between 'Age' and 'Salary'.

# %%
data1.Weight.value_counts()
# Out:
# Weight
# 220    29
# 240    28
# 250    26
# 200    25
# 205    22
#        ..
# 229     1
# 192     1
# 249     1
# 217     1
# 256     1
# Name: count, Length: 87, dtype: int64

# %%
plt.hist(data1['Weight'], color = 'purple', edgecolor = 'black') 
plt.title('Frequency distribution of Weight')
plt.xlabel('Weight') 
plt.ylabel('Frequency')
plt.xlim(140, 320)
plt.ylim(0, 140)
plt.show()

# %% [markdown]
# ### **Data Story**
# Frequency distribution of weight of employees.

# %%
sns.pairplot(data = data1, hue = "Position")
plt.show()

# %% [markdown]
# ### **Data Story**
# Corelations of different combinations of variable.

# %%
data2 = pd.DataFrame({"Age": data1['Age'], "Salary": data1['Salary'], "Weight": data1['Weight'], "Height": data1['Height']}) 
data2
# Out:
#      Age          Salary  Weight  Height
# 0     25       7730337.0     180     167
# 1     25       6796117.0     235     164
# 2     27  4833969.545861     205     171
# 3     22       1148640.0     185     161
# 4     29       5000000.0     231     166
# ..   ...             ...     ...     ...
# 453   26       2433333.0     203     169
# 454   24        900000.0     179     160
# 455   26       2900000.0     256     176
# 456   26        947276.0     231     163
# 457   25        947276.0     231     166
#
# [458 rows x 4 columns]

# %%
data2.corr()
# Out:
#              Age    Salary    Weight    Height
# Age     1.000000  0.211170  0.086806 -0.003848
# Salary  0.211170  1.000000  0.134871 -0.030373
# Weight  0.086806  0.134871  1.000000 -0.046474
# Height -0.003848 -0.030373 -0.046474  1.000000

# %% [markdown]
# ### **Data Story**
# The above table represents the corelation matrix.

# %%
sns.heatmap(data2.corr(), annot=True, cmap="coolwarm") 

plt.show()

# %% [markdown]
# ### **Data Story**
# Visual representation of the corelation matrix.

# %% [markdown]
# # ****Conclusion of ABC Company Employee Analysis****
#
# The analysis of the employee dataset for ABC Company was conducted to gain insights into the workforce distribution across various teams, positions, and age groups, as well as to examine salary spending and potential correlations between age and salary. The key findings are summarized as follows:
#
# 1. **Employee Distribution by Team:**
#
#    * The number of employees in each team was calculated, and the percentage distribution was also determined. This provides a clear understanding of workforce concentration in each team, helping the management assess which teams are overstaffed or understaffed.
#
# 2. **Segregation by Position:**
#
#    * The employees were categorized based on their respective positions. This segmentation provides insights into the hierarchy structure and the number of employees in each role, enabling more targeted workforce planning and optimization.
#
# 3. **Age Group Analysis:**
#
#    * The workforce was divided into age groups to identify which age bracket has the highest representation in the company. This information can be crucial in planning training and skill development programs tailored to specific age groups.
#
# 4. **Salary Spending Analysis:**
#
#    * A detailed analysis was performed to determine the team and position that incur the highest salary expenditures. This helps in understanding resource allocation and budget optimization within the organization.
#
# 5. **Correlation Analysis between Age and Salary:**
#
#    * A correlation analysis between age and salary was conducted to explore potential relationships. Visual representation through a scatter plot was also generated, aiding in identifying any observable patterns or outliers in the dataset.
#
# Additionally, data preprocessing steps, such as updating incorrect values in the 'Height' column with realistic random values, were performed to ensure data integrity.
#
# Overall, the analysis provides comprehensive insights into the workforce structure, salary distribution, and potential areas for strategic intervention, supporting data-driven decision-making for ABC Company.
